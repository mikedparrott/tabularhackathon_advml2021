# %% [markdown]
# <p align="center"><img width="50%" src="https://aimodelsharecontent.s3.amazonaws.com/aimodshare_banner.jpg" /></p>
#
#
# ---

# %% [markdown]
# ## Model Submission Guide: Titanic Survival Competition
# Let's share our models to a centralized leaderboard, so that we can collaborate and learn from the model experimentation process...
#
# **Instructions:**
# 1.   Get data in and set up X_train / X_test / y_train
# 2.   Preprocess data using Sklearn Column Transformer/ Write and Save Preprocessor function
# 3. Fit model on preprocessed data and save preprocessor function and model
# 4. Generate predictions from X_test data and submit model to competition
# 5. Repeat submission process to improve place on leaderboard

# %% [markdown]
# ## 1. Get data in and set up X_train, X_test, y_train objects

# %%
#install aimodelshare library
! pip install aimodelshare --upgrade

# %%
# Get competition data
# Separate data into X_train, y_train, and X_test
import pandas as pd
training_data=pd.read_csv("training_data.csv")
y_train_labels = training_data['survived']
X_train = training_data.drop(['survived'], axis=1)

X_test=pd.read_csv("test_data.csv")

X_train.head()
# Out:
#    pclass     sex   age     fare embarked
# 0       3    male   NaN  15.5000        Q
# 1       2  female  18.0  13.0000        S
# 2       2    male  36.0  27.7500        S
# 3       2  female  22.0  41.5792        C
# 4       2  female  24.0  27.7208        C

# %% [markdown]
# ##2.   Preprocess data using Sklearn Column Transformer/ Write and Save Preprocessor function

# %%
# In this case we use Sklearn's Column transformer in our preprocessor function

from sklearn.compose import ColumnTransformer
from sklearn.pipeline import Pipeline
from sklearn.impute import SimpleImputer
from sklearn.preprocessing import StandardScaler, OneHotEncoder

#Preprocess data using sklearn's Column Transformer approach

# We create the preprocessing pipelines for both numeric and categorical data.
numeric_features = ['age', 'fare']
numeric_transformer = Pipeline(steps=[
    ('imputer', SimpleImputer(strategy='median')), #'imputer' names the step
    ('scaler', StandardScaler())])

categorical_features = ['embarked', 'sex', 'pclass']

# Replacing missing values with Modal value and then one-hot encoding.
categorical_transformer = Pipeline(steps=[
    ('imputer', SimpleImputer(strategy='most_frequent')),
    ('onehot', OneHotEncoder(handle_unknown='ignore'))])

# Final preprocessor object set up with ColumnTransformer...

preprocess = ColumnTransformer(
    transformers=[
        ('num', numeric_transformer, numeric_features),
        ('cat', categorical_transformer, categorical_features)])

# fit preprocessor to your data
preprocess = preprocess.fit(X_train)

# %%
# Here is where we actually write the preprocessor function:

# Write function to transform data with preprocessor
# In this case we use sklearn's Column transformer in our preprocessor function

def preprocessor(data):
    preprocessed_data=preprocess.transform(data)
    return preprocessed_data

# %%
# check shape of X data after preprocessing it using our new function
preprocessor(X_train).shape
# Out:
# (1047, 10)

# %% [markdown]
# ##3. Fit model on preprocessed data and save preprocessor function and model

# %%
from sklearn.linear_model import LogisticRegression

model = LogisticRegression(C=10, penalty='l1', solver = 'liblinear')
model.fit(preprocessor(X_train), y_train_labels) # Fitting to the training set.
model.score(preprocessor(X_train), y_train_labels) # Fit score, 0-1 scale.
# Out:
# 0.6991404011461319

# %% [markdown]
# #### Save preprocessor function to local "preprocessor.zip" file

# %%
import aimodelshare as ai
ai.export_preprocessor(preprocessor,"")
# Out:
# Your preprocessor is now saved to 'preprocessor.zip'

# %% [markdown]
# ## 4. Generate predictions from X_test data and submit model to competition

# %%
#Set credentials using modelshare.org username/password

from aimodelshare.aws import set_credentials

#This is the unique rest api that powers this Titanic Survival Playground -- make sure to update the apiurl for new competition deployments
apiurl='https://y32zyyf6t5.execute-api.us-east-2.amazonaws.com/prod/m'

set_credentials(apiurl=apiurl)
# Out:
# Modelshare.ai Username:··········
# Modelshare.ai Password:··········
# Modelshare.ai login credentials set successfully.

# %%
#Instantiate Competition
import aimodelshare as ai
mycompetition= ai.ModelPlayground(playground_url=apiurl)

# %%
#Submit Model 1:

#-- Generate predicted values (a list of predicted labels "survived" or "died") (Model 1)
prediction_labels = model.predict(preprocessor(X_test))

# Submit Model 1 to Competition Leaderboard
mycompetition.submit_model(      model=model,
                                 preprocessor="preprocessor.zip",
                                 prediction_submission=prediction_labels)
# Out:
# This ORT build has ['AzureExecutionProvider', 'CPUExecutionProvider'] enabled. Since ORT 1.9, you are required to explicitly set the providers parameter when instantiating InferenceSession. For example, onnxruntime.InferenceSession(..., providers=['AzureExecutionProvider', 'CPUExecutionProvider'], ...)
#
# Insert search tags to help users find your model (optional):
# Provide any useful notes about your model (optional):
# Your model has been submitted to experiment as model version 5.
#
# Visit your Model Playground Page for more.
# https://www.modelshare.ai/detail/model:3860

# %%
# Get leaderboard to explore current best model architectures

# Get raw data in pandas data frame
data = mycompetition.get_leaderboard()

# Stylize leaderboard data
mycompetition.stylize_leaderboard(data)
# Out:
# <style type="text/css">
# #T_f816f_row0_col0, #T_f816f_row1_col0, #T_f816f_row2_col0 {
#   text-align: center;
#   width: 10em;
#   background: linear-gradient(90deg, #f5f8d6 82.8%, transparent 82.8%);
#   color: #251e1b;
#   font-size: 12px;
# }
# #T_f816f_row0_col1, #T_f816f_row1_col1, #T_f816f_row2_col1 {
#   text-align: center;
#   width: 10em;
#   background: linear-gradient(90deg, #c778c8 81.3%, transparent 81.3%);
#   color: #251e1b;
#   font-size: 12px;
# }
# #T_f816f_row0_col2, #T_f816f_row1_col2, #T_f816f_row2_col2 {
#   text-align: center;
#   width: 10em;
#   background: linear-gradient(90deg, #ff4971 81.7%, transparent 81.7%);
#   color: #251e1b;
#   font-size: 12px;
# }
# #T_f816f_row0_col3, #T_f816f_row1_col3, #T_f816f_row2_col3 {
#   text-align: center;
#   width: 10em;
#   background: linear-gradient(90deg, #aadbaa 81.0%, transparent 81.0%);
#   color: #251e1b;
#   font-size: 12px;
# }
# #T_f816f_row0_col4, #T_f816f_row0_col5, #T_f816f_row0_col6, #T_f816f_row0_col7, #T_f816f_row0_col8, #T_f816f_row0_col9, #T_f816f_row1_col4, #T_f816f_row1_col5, #T_f816f_row1_col6, #T_f816f_row1_col7, #T_f816f_row1_col8, #T_f816f_row1_col9, #T_f816f_row2_col4, #T_f816f_row2_col5, #T_f816f_row2_col6, #T_f816f_row2_col7, #T_f816f_row2_col8, #T_f816f_row2_col9, #T_f816f_row3_col4, #T_f816f_row3_col5, #T_f816f_row3_col6, #T_f816f_row3_col7, #T_f816f_row3_col8, #T_f816f_row3_col9, #T_f816f_row4_col4, #T_f816f_row4_col5, #T_f816f_row4_col6, #T_f816f_row4_col7, #T_f816f_row4_col8, #T_f816f_row4_col9 {
#   text-align: center;
# }
# #T_f816f_row3_col0 {
#   text-align: center;
#   width: 10em;
#   background: linear-gradient(90deg, #f5f8d6 76.7%, transparent 76.7%);
#   color: #251e1b;
#   font-size: 12px;
# }
# #T_f816f_row3_col1 {
#   text-align: center;
#   width: 10em;
#   background: linear-gradient(90deg, #c778c8 69.3%, transparent 69.3%);
#   color: #251e1b;
#   font-size: 12px;
# }
# #T_f816f_row3_col2 {
#   text-align: center;
#   width: 10em;
#   background: linear-gradient(90deg, #ff4971 85.3%, transparent 85.3%);
#   color: #251e1b;
#   font-size: 12px;
# }
# #T_f816f_row3_col3 {
#   text-align: center;
#   width: 10em;
#   background: linear-gradient(90deg, #aadbaa 68.4%, transparent 68.4%);
#   color: #251e1b;
#   font-size: 12px;
# }
# #T_f816f_row4_col0 {
#   text-align: center;
#   width: 10em;
#   background: linear-gradient(90deg, #f5f8d6 50.4%, transparent 50.4%);
#   color: #251e1b;
#   font-size: 12px;
# }
# #T_f816f_row4_col1 {
#   text-align: center;
#   width: 10em;
#   background: linear-gradient(90deg, #c778c8 45.6%, transparent 45.6%);
#   color: #251e1b;
#   font-size: 12px;
# }
# #T_f816f_row4_col2 {
#   text-align: center;
#   width: 10em;
#   background: linear-gradient(90deg, #ff4971 45.5%, transparent 45.5%);
#   color: #251e1b;
#   font-size: 12px;
# }
# #T_f816f_row4_col3 {
#   text-align: center;
#   width: 10em;
#   background: linear-gradient(90deg, #aadbaa 45.7%, transparent 45.7%);
#   color: #251e1b;
#   font-size: 12px;
# }
# </style>
# <table id="T_f816f" class="dataframe">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_f816f_level0_col0" class="col_heading level0 col0" >accuracy</th>
#       <th id="T_f816f_level0_col1" class="col_heading level0 col1" >f1_score</th>
#       <th id="T_f816f_level0_col2" class="col_heading level0 col2" >precision</th>
#       <th id="T_f816f_level0_col3" class="col_heading level0 col3" >recall</th>
#       <th id="T_f816f_level0_col4" class="col_heading level0 col4" >ml_framework</th>
#       <th id="T_f816f_level0_col5" class="col_heading level0 col5" >model_type</th>
#       <th id="T_f816f_level0_col6" class="col_heading level0 col6" >num_params</th>
#       <th id="T_f816f_level0_col7" class="col_heading level0 col7" >optimizer</th>
#       <th id="T_f816f_level0_col8" class="col_heading level0 col8" >username</th>
#       <th id="T_f816f_level0_col9" class="col_heading level0 col9" >version</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_f816f_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_f816f_row0_col0" class="data row0 col0" >82.82%</td>
#       <td id="T_f816f_row0_col1" class="data row0 col1" >81.29%</td>
#       <td id="T_f816f_row0_col2" class="data row0 col2" >81.70%</td>
#       <td id="T_f816f_row0_col3" class="data row0 col3" >80.96%</td>
#       <td id="T_f816f_row0_col4" class="data row0 col4" >sklearn</td>
#       <td id="T_f816f_row0_col5" class="data row0 col5" >LogisticRegression</td>
#       <td id="T_f816f_row0_col6" class="data row0 col6" >10</td>
#       <td id="T_f816f_row0_col7" class="data row0 col7" >liblinear</td>
#       <td id="T_f816f_row0_col8" class="data row0 col8" >mikedparrott</td>
#       <td id="T_f816f_row0_col9" class="data row0 col9" >1</td>
#     </tr>
#     <tr>
#       <th id="T_f816f_level0_row1" class="row_heading level0 row1" >1</th>
#       <td id="T_f816f_row1_col0" class="data row1 col0" >82.82%</td>
#       <td id="T_f816f_row1_col1" class="data row1 col1" >81.29%</td>
#       <td id="T_f816f_row1_col2" class="data row1 col2" >81.70%</td>
#       <td id="T_f816f_row1_col3" class="data row1 col3" >80.96%</td>
#       <td id="T_f816f_row1_col4" class="data row1 col4" >sklearn</td>
#       <td id="T_f816f_row1_col5" class="data row1 col5" >LogisticRegression</td>
#       <td id="T_f816f_row1_col6" class="data row1 col6" >10</td>
#       <td id="T_f816f_row1_col7" class="data row1 col7" >liblinear</td>
#       <td id="T_f816f_row1_col8" class="data row1 col8" >newusertest</td>
#       <td id="T_f816f_row1_col9" class="data row1 col9" >3</td>
#     </tr>
#     <tr>
#       <th id="T_f816f_level0_row2" class="row_heading level0 row2" >2</th>
#       <td id="T_f816f_row2_col0" class="data row2 col0" >82.82%</td>
#       <td id="T_f816f_row2_col1" class="data row2 col1" >81.29%</td>
#       <td id="T_f816f_row2_col2" class="data row2 col2" >81.70%</td>
#       <td id="T_f816f_row2_col3" class="data row2 col3" >80.96%</td>
#       <td id="T_f816f_row2_col4" class="data row2 col4" >sklearn</td>
#       <td id="T_f816f_row2_col5" class="data row2 col5" >LogisticRegression</td>
#       <td id="T_f816f_row2_col6" class="data row2 col6" >10</td>
#       <td id="T_f816f_row2_col7" class="data row2 col7" >liblinear</td>
#       <td id="T_f816f_row2_col8" class="data row2 col8" >newusertest</td>
#       <td id="T_f816f_row2_col9" class="data row2 col9" >4</td>
#     </tr>
#     <tr>
#       <th id="T_f816f_level0_row3" class="row_heading level0 row3" >3</th>
#       <td id="T_f816f_row3_col0" class="data row3 col0" >76.72%</td>
#       <td id="T_f816f_row3_col1" class="data row3 col1" >69.27%</td>
#       <td id="T_f816f_row3_col2" class="data row3 col2" >85.32%</td>
#       <td id="T_f816f_row3_col3" class="data row3 col3" >68.45%</td>
#       <td id="T_f816f_row3_col4" class="data row3 col4" >sklearn</td>
#       <td id="T_f816f_row3_col5" class="data row3 col5" >LogisticRegression</td>
#       <td id="T_f816f_row3_col6" class="data row3 col6" >10</td>
#       <td id="T_f816f_row3_col7" class="data row3 col7" >liblinear</td>
#       <td id="T_f816f_row3_col8" class="data row3 col8" >newusertest</td>
#       <td id="T_f816f_row3_col9" class="data row3 col9" >5</td>
#     </tr>
#     <tr>
#       <th id="T_f816f_level0_row4" class="row_heading level0 row4" >4</th>
#       <td id="T_f816f_row4_col0" class="data row4 col0" >50.38%</td>
#       <td id="T_f816f_row4_col1" class="data row4 col1" >45.56%</td>
#       <td id="T_f816f_row4_col2" class="data row4 col2" >45.51%</td>
#       <td id="T_f816f_row4_col3" class="data row4 col3" >45.69%</td>
#       <td id="T_f816f_row4_col4" class="data row4 col4" >sklearn</td>
#       <td id="T_f816f_row4_col5" class="data row4 col5" >LogisticRegression</td>
#       <td id="T_f816f_row4_col6" class="data row4 col6" >10</td>
#       <td id="T_f816f_row4_col7" class="data row4 col7" >liblinear</td>
#       <td id="T_f816f_row4_col8" class="data row4 col8" >newusertest</td>
#       <td id="T_f816f_row4_col9" class="data row4 col9" >2</td>
#     </tr>
#   </tbody>
# </table>

# %% [markdown]
# ## 5. Repeat submission process to improve place on leaderboard

# %%
# Train and submit model 2 using same preprocessor (note that you could save a new preprocessor, but we will use the same one for this example).
from sklearn.linear_model import LogisticRegression

model_2 = LogisticRegression(C=.01, penalty='l2')
model_2.fit(preprocessor(X_train), y_train_labels) # Fitting to the training set.
model_2.score(preprocessor(X_train), y_train_labels) # Fit score, 0-1 scale.
# Out:
# 0.7583572110792741

# %%
#Submit Model 2:

#-- Generate predicted y values (Model 2)
prediction_labels = model_2.predict(preprocessor(X_test))

# Submit Model 2 to Competition Leaderboard
mycompetition.submit_model(model = model_2,
                                 preprocessor="preprocessor.zip",

                           prediction_submission=prediction_labels)
# Out:
# This ORT build has ['AzureExecutionProvider', 'CPUExecutionProvider'] enabled. Since ORT 1.9, you are required to explicitly set the providers parameter when instantiating InferenceSession. For example, onnxruntime.InferenceSession(..., providers=['AzureExecutionProvider', 'CPUExecutionProvider'], ...)
#
# Insert search tags to help users find your model (optional):
# Provide any useful notes about your model (optional):
# Your model has been submitted to experiment as model version 6.
#
# Visit your Model Playground Page for more.
# https://www.modelshare.ai/detail/model:3860

# %%
# Compare two or more models
data=mycompetition.compare_models([1,5], verbose=1)
mycompetition.stylize_compare(data)
# Out:
# <style type="text/css">
# #T_2811c caption {
#   color: black;
#   font-size: 18px;
# }
# #T_2811c_row0_col2, #T_2811c_row0_col3, #T_2811c_row9_col2, #T_2811c_row9_col3, #T_2811c_row11_col2, #T_2811c_row11_col3 {
#   background: tomato;
# }
# </style>
# <table id="T_2811c">
#   <caption>Model type: LogisticRegression</caption>
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_2811c_level0_col0" class="col_heading level0 col0" >param_name</th>
#       <th id="T_2811c_level0_col1" class="col_heading level0 col1" >default_value</th>
#       <th id="T_2811c_level0_col2" class="col_heading level0 col2" >model_version_1</th>
#       <th id="T_2811c_level0_col3" class="col_heading level0 col3" >model_version_5</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_2811c_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_2811c_row0_col0" class="data row0 col0" >C</td>
#       <td id="T_2811c_row0_col1" class="data row0 col1" >1.000000</td>
#       <td id="T_2811c_row0_col2" class="data row0 col2" >10</td>
#       <td id="T_2811c_row0_col3" class="data row0 col3" >0.010000</td>
#     </tr>
#     <tr>
#       <th id="T_2811c_level0_row1" class="row_heading level0 row1" >1</th>
#       <td id="T_2811c_row1_col0" class="data row1 col0" >class_weight</td>
#       <td id="T_2811c_row1_col1" class="data row1 col1" >None</td>
#       <td id="T_2811c_row1_col2" class="data row1 col2" >None</td>
#       <td id="T_2811c_row1_col3" class="data row1 col3" >None</td>
#     </tr>
#     <tr>
#       <th id="T_2811c_level0_row2" class="row_heading level0 row2" >2</th>
#       <td id="T_2811c_row2_col0" class="data row2 col0" >dual</td>
#       <td id="T_2811c_row2_col1" class="data row2 col1" >False</td>
#       <td id="T_2811c_row2_col2" class="data row2 col2" >False</td>
#       <td id="T_2811c_row2_col3" class="data row2 col3" >False</td>
#     </tr>
#     <tr>
#       <th id="T_2811c_level0_row3" class="row_heading level0 row3" >3</th>
#       <td id="T_2811c_row3_col0" class="data row3 col0" >fit_intercept</td>
#       <td id="T_2811c_row3_col1" class="data row3 col1" >True</td>
#       <td id="T_2811c_row3_col2" class="data row3 col2" >True</td>
#       <td id="T_2811c_row3_col3" class="data row3 col3" >True</td>
#     </tr>
#     <tr>
#       <th id="T_2811c_level0_row4" class="row_heading level0 row4" >4</th>
#       <td id="T_2811c_row4_col0" class="data row4 col0" >intercept_scaling</td>
#       <td id="T_2811c_row4_col1" class="data row4 col1" >1</td>
#       <td id="T_2811c_row4_col2" class="data row4 col2" >1</td>
#       <td id="T_2811c_row4_col3" class="data row4 col3" >1</td>
#     </tr>
#     <tr>
#       <th id="T_2811c_level0_row5" class="row_heading level0 row5" >5</th>
#       <td id="T_2811c_row5_col0" class="data row5 col0" >l1_ratio</td>
#       <td id="T_2811c_row5_col1" class="data row5 col1" >None</td>
#       <td id="T_2811c_row5_col2" class="data row5 col2" >None</td>
#       <td id="T_2811c_row5_col3" class="data row5 col3" >None</td>
#     </tr>
#     <tr>
#       <th id="T_2811c_level0_row6" class="row_heading level0 row6" >6</th>
#       <td id="T_2811c_row6_col0" class="data row6 col0" >max_iter</td>
#       <td id="T_2811c_row6_col1" class="data row6 col1" >100</td>
#       <td id="T_2811c_row6_col2" class="data row6 col2" >100</td>
#       <td id="T_2811c_row6_col3" class="data row6 col3" >100</td>
#     </tr>
#     <tr>
#       <th id="T_2811c_level0_row7" class="row_heading level0 row7" >7</th>
#       <td id="T_2811c_row7_col0" class="data row7 col0" >multi_class</td>
#       <td id="T_2811c_row7_col1" class="data row7 col1" >auto</td>
#       <td id="T_2811c_row7_col2" class="data row7 col2" >auto</td>
#       <td id="T_2811c_row7_col3" class="data row7 col3" >auto</td>
#     </tr>
#     <tr>
#       <th id="T_2811c_level0_row8" class="row_heading level0 row8" >8</th>
#       <td id="T_2811c_row8_col0" class="data row8 col0" >n_jobs</td>
#       <td id="T_2811c_row8_col1" class="data row8 col1" >None</td>
#       <td id="T_2811c_row8_col2" class="data row8 col2" >None</td>
#       <td id="T_2811c_row8_col3" class="data row8 col3" >None</td>
#     </tr>
#     <tr>
#       <th id="T_2811c_level0_row9" class="row_heading level0 row9" >9</th>
#       <td id="T_2811c_row9_col0" class="data row9 col0" >penalty</td>
#       <td id="T_2811c_row9_col1" class="data row9 col1" >l2</td>
#       <td id="T_2811c_row9_col2" class="data row9 col2" >l1</td>
#       <td id="T_2811c_row9_col3" class="data row9 col3" >l1</td>
#     </tr>
#     <tr>
#       <th id="T_2811c_level0_row10" class="row_heading level0 row10" >10</th>
#       <td id="T_2811c_row10_col0" class="data row10 col0" >random_state</td>
#       <td id="T_2811c_row10_col1" class="data row10 col1" >None</td>
#       <td id="T_2811c_row10_col2" class="data row10 col2" >None</td>
#       <td id="T_2811c_row10_col3" class="data row10 col3" >None</td>
#     </tr>
#     <tr>
#       <th id="T_2811c_level0_row11" class="row_heading level0 row11" >11</th>
#       <td id="T_2811c_row11_col0" class="data row11 col0" >solver</td>
#       <td id="T_2811c_row11_col1" class="data row11 col1" >lbfgs</td>
#       <td id="T_2811c_row11_col2" class="data row11 col2" >liblinear</td>
#       <td id="T_2811c_row11_col3" class="data row11 col3" >liblinear</td>
#     </tr>
#     <tr>
#       <th id="T_2811c_level0_row12" class="row_heading level0 row12" >12</th>
#       <td id="T_2811c_row12_col0" class="data row12 col0" >tol</td>
#       <td id="T_2811c_row12_col1" class="data row12 col1" >0.000100</td>
#       <td id="T_2811c_row12_col2" class="data row12 col2" >0.000100</td>
#       <td id="T_2811c_row12_col3" class="data row12 col3" >0.000100</td>
#     </tr>
#     <tr>
#       <th id="T_2811c_level0_row13" class="row_heading level0 row13" >13</th>
#       <td id="T_2811c_row13_col0" class="data row13 col0" >verbose</td>
#       <td id="T_2811c_row13_col1" class="data row13 col1" >0</td>
#       <td id="T_2811c_row13_col2" class="data row13 col2" >0</td>
#       <td id="T_2811c_row13_col3" class="data row13 col3" >0</td>
#     </tr>
#     <tr>
#       <th id="T_2811c_level0_row14" class="row_heading level0 row14" >14</th>
#       <td id="T_2811c_row14_col0" class="data row14 col0" >warm_start</td>
#       <td id="T_2811c_row14_col1" class="data row14 col1" >False</td>
#       <td id="T_2811c_row14_col2" class="data row14 col2" >False</td>
#       <td id="T_2811c_row14_col3" class="data row14 col3" >False</td>
#     </tr>
#   </tbody>
# </table>

# %%
# Submit a third model using GridSearchCV

from sklearn.ensemble import RandomForestClassifier
from sklearn.model_selection import GridSearchCV
import numpy as np

param_grid = {'n_estimators': np.arange(100, 300, 500),'max_depth':[1, 3, 5]} #np.arange creates sequence of numbers for each k value

gridmodel = GridSearchCV(RandomForestClassifier(), param_grid=param_grid, cv=10)

#use meta model methods to fit score and predict model:
gridmodel.fit(preprocessor(X_train), y_train_labels)

#extract best score and parameter by calling objects "best_score_" and "best_params_"
print("best mean cross-validation score: {:.3f}".format(gridmodel.best_score_))
print("best parameters: {}".format(gridmodel.best_params_))
# Out:
# best mean cross-validation score: 0.796
# best parameters: {'max_depth': 5, 'n_estimators': 100}

# %%
#Submit Model 3:

#-- Generate predicted values
prediction_labels = gridmodel.predict(preprocessor(X_test))

# Submit to Competition Leaderboard
mycompetition.submit_model(model = gridmodel,
                                 preprocessor="preprocessor.zip",
                                 prediction_submission=prediction_labels)
# Out:
# This ORT build has ['AzureExecutionProvider', 'CPUExecutionProvider'] enabled. Since ORT 1.9, you are required to explicitly set the providers parameter when instantiating InferenceSession. For example, onnxruntime.InferenceSession(..., providers=['AzureExecutionProvider', 'CPUExecutionProvider'], ...)
#
# Insert search tags to help users find your model (optional):
# Provide any useful notes about your model (optional):
# Your model has been submitted to experiment as model version 7.
#
# Visit your Model Playground Page for more.
# https://www.modelshare.ai/detail/model:3860

# %%
# Get leaderboard

data = mycompetition.get_leaderboard()
mycompetition.stylize_leaderboard(data)
# Out:
# <style type="text/css">
# #T_fa948_row0_col0 {
#   text-align: center;
#   width: 10em;
#   background: linear-gradient(90deg, #f5f8d6 85.1%, transparent 85.1%);
#   color: #251e1b;
#   font-size: 12px;
# }
# #T_fa948_row0_col1 {
#   text-align: center;
#   width: 10em;
#   background: linear-gradient(90deg, #c778c8 83.2%, transparent 83.2%);
#   color: #251e1b;
#   font-size: 12px;
# }
# #T_fa948_row0_col2 {
#   text-align: center;
#   width: 10em;
#   background: linear-gradient(90deg, #ff4971 85.7%, transparent 85.7%);
#   color: #251e1b;
#   font-size: 12px;
# }
# #T_fa948_row0_col3 {
#   text-align: center;
#   width: 10em;
#   background: linear-gradient(90deg, #aadbaa 81.9%, transparent 81.9%);
#   color: #251e1b;
#   font-size: 12px;
# }
# #T_fa948_row0_col4, #T_fa948_row0_col5, #T_fa948_row0_col6, #T_fa948_row0_col7, #T_fa948_row0_col8, #T_fa948_row0_col9, #T_fa948_row1_col4, #T_fa948_row1_col5, #T_fa948_row1_col6, #T_fa948_row1_col7, #T_fa948_row1_col8, #T_fa948_row1_col9, #T_fa948_row2_col4, #T_fa948_row2_col5, #T_fa948_row2_col6, #T_fa948_row2_col7, #T_fa948_row2_col8, #T_fa948_row2_col9, #T_fa948_row3_col4, #T_fa948_row3_col5, #T_fa948_row3_col6, #T_fa948_row3_col7, #T_fa948_row3_col8, #T_fa948_row3_col9, #T_fa948_row4_col4, #T_fa948_row4_col5, #T_fa948_row4_col6, #T_fa948_row4_col7, #T_fa948_row4_col8, #T_fa948_row4_col9, #T_fa948_row5_col4, #T_fa948_row5_col5, #T_fa948_row5_col6, #T_fa948_row5_col7, #T_fa948_row5_col8, #T_fa948_row5_col9, #T_fa948_row6_col4, #T_fa948_row6_col5, #T_fa948_row6_col6, #T_fa948_row6_col7, #T_fa948_row6_col8, #T_fa948_row6_col9, #T_fa948_row7_col4, #T_fa948_row7_col5, #T_fa948_row7_col6, #T_fa948_row7_col7, #T_fa948_row7_col8, #T_fa948_row7_col9 {
#   text-align: center;
# }
# #T_fa948_row1_col0, #T_fa948_row2_col0, #T_fa948_row3_col0, #T_fa948_row5_col0 {
#   text-align: center;
#   width: 10em;
#   background: linear-gradient(90deg, #f5f8d6 82.8%, transparent 82.8%);
#   color: #251e1b;
#   font-size: 12px;
# }
# #T_fa948_row1_col1, #T_fa948_row2_col1, #T_fa948_row3_col1 {
#   text-align: center;
#   width: 10em;
#   background: linear-gradient(90deg, #c778c8 81.3%, transparent 81.3%);
#   color: #251e1b;
#   font-size: 12px;
# }
# #T_fa948_row1_col2, #T_fa948_row2_col2, #T_fa948_row3_col2 {
#   text-align: center;
#   width: 10em;
#   background: linear-gradient(90deg, #ff4971 81.7%, transparent 81.7%);
#   color: #251e1b;
#   font-size: 12px;
# }
# #T_fa948_row1_col3, #T_fa948_row2_col3, #T_fa948_row3_col3 {
#   text-align: center;
#   width: 10em;
#   background: linear-gradient(90deg, #aadbaa 81.0%, transparent 81.0%);
#   color: #251e1b;
#   font-size: 12px;
# }
# #T_fa948_row4_col0 {
#   text-align: center;
#   width: 10em;
#   background: linear-gradient(90deg, #f5f8d6 83.6%, transparent 83.6%);
#   color: #251e1b;
#   font-size: 12px;
# }
# #T_fa948_row4_col1, #T_fa948_row5_col1 {
#   text-align: center;
#   width: 10em;
#   background: linear-gradient(90deg, #c778c8 81.1%, transparent 81.1%);
#   color: #251e1b;
#   font-size: 12px;
# }
# #T_fa948_row4_col2 {
#   text-align: center;
#   width: 10em;
#   background: linear-gradient(90deg, #ff4971 84.8%, transparent 84.8%);
#   color: #251e1b;
#   font-size: 12px;
# }
# #T_fa948_row4_col3 {
#   text-align: center;
#   width: 10em;
#   background: linear-gradient(90deg, #aadbaa 79.6%, transparent 79.6%);
#   color: #251e1b;
#   font-size: 12px;
# }
# #T_fa948_row5_col2 {
#   text-align: center;
#   width: 10em;
#   background: linear-gradient(90deg, #ff4971 81.9%, transparent 81.9%);
#   color: #251e1b;
#   font-size: 12px;
# }
# #T_fa948_row5_col3 {
#   text-align: center;
#   width: 10em;
#   background: linear-gradient(90deg, #aadbaa 80.5%, transparent 80.5%);
#   color: #251e1b;
#   font-size: 12px;
# }
# #T_fa948_row6_col0 {
#   text-align: center;
#   width: 10em;
#   background: linear-gradient(90deg, #f5f8d6 76.7%, transparent 76.7%);
#   color: #251e1b;
#   font-size: 12px;
# }
# #T_fa948_row6_col1 {
#   text-align: center;
#   width: 10em;
#   background: linear-gradient(90deg, #c778c8 69.3%, transparent 69.3%);
#   color: #251e1b;
#   font-size: 12px;
# }
# #T_fa948_row6_col2 {
#   text-align: center;
#   width: 10em;
#   background: linear-gradient(90deg, #ff4971 85.3%, transparent 85.3%);
#   color: #251e1b;
#   font-size: 12px;
# }
# #T_fa948_row6_col3 {
#   text-align: center;
#   width: 10em;
#   background: linear-gradient(90deg, #aadbaa 68.4%, transparent 68.4%);
#   color: #251e1b;
#   font-size: 12px;
# }
# #T_fa948_row7_col0 {
#   text-align: center;
#   width: 10em;
#   background: linear-gradient(90deg, #f5f8d6 50.4%, transparent 50.4%);
#   color: #251e1b;
#   font-size: 12px;
# }
# #T_fa948_row7_col1 {
#   text-align: center;
#   width: 10em;
#   background: linear-gradient(90deg, #c778c8 45.6%, transparent 45.6%);
#   color: #251e1b;
#   font-size: 12px;
# }
# #T_fa948_row7_col2 {
#   text-align: center;
#   width: 10em;
#   background: linear-gradient(90deg, #ff4971 45.5%, transparent 45.5%);
#   color: #251e1b;
#   font-size: 12px;
# }
# #T_fa948_row7_col3 {
#   text-align: center;
#   width: 10em;
#   background: linear-gradient(90deg, #aadbaa 45.7%, transparent 45.7%);
#   color: #251e1b;
#   font-size: 12px;
# }
# </style>
# <table id="T_fa948" class="dataframe">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_fa948_level0_col0" class="col_heading level0 col0" >accuracy</th>
#       <th id="T_fa948_level0_col1" class="col_heading level0 col1" >f1_score</th>
#       <th id="T_fa948_level0_col2" class="col_heading level0 col2" >precision</th>
#       <th id="T_fa948_level0_col3" class="col_heading level0 col3" >recall</th>
#       <th id="T_fa948_level0_col4" class="col_heading level0 col4" >ml_framework</th>
#       <th id="T_fa948_level0_col5" class="col_heading level0 col5" >model_type</th>
#       <th id="T_fa948_level0_col6" class="col_heading level0 col6" >num_params</th>
#       <th id="T_fa948_level0_col7" class="col_heading level0 col7" >optimizer</th>
#       <th id="T_fa948_level0_col8" class="col_heading level0 col8" >username</th>
#       <th id="T_fa948_level0_col9" class="col_heading level0 col9" >version</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_fa948_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_fa948_row0_col0" class="data row0 col0" >85.11%</td>
#       <td id="T_fa948_row0_col1" class="data row0 col1" >83.17%</td>
#       <td id="T_fa948_row0_col2" class="data row0 col2" >85.67%</td>
#       <td id="T_fa948_row0_col3" class="data row0 col3" >81.88%</td>
#       <td id="T_fa948_row0_col4" class="data row0 col4" >sklearn</td>
#       <td id="T_fa948_row0_col5" class="data row0 col5" >RandomForestClassifier</td>
#       <td id="T_fa948_row0_col6" class="data row0 col6" >nan</td>
#       <td id="T_fa948_row0_col7" class="data row0 col7" >nan</td>
#       <td id="T_fa948_row0_col8" class="data row0 col8" >newusertest</td>
#       <td id="T_fa948_row0_col9" class="data row0 col9" >7</td>
#     </tr>
#     <tr>
#       <th id="T_fa948_level0_row1" class="row_heading level0 row1" >1</th>
#       <td id="T_fa948_row1_col0" class="data row1 col0" >82.82%</td>
#       <td id="T_fa948_row1_col1" class="data row1 col1" >81.29%</td>
#       <td id="T_fa948_row1_col2" class="data row1 col2" >81.70%</td>
#       <td id="T_fa948_row1_col3" class="data row1 col3" >80.96%</td>
#       <td id="T_fa948_row1_col4" class="data row1 col4" >sklearn</td>
#       <td id="T_fa948_row1_col5" class="data row1 col5" >LogisticRegression</td>
#       <td id="T_fa948_row1_col6" class="data row1 col6" >10.000000</td>
#       <td id="T_fa948_row1_col7" class="data row1 col7" >liblinear</td>
#       <td id="T_fa948_row1_col8" class="data row1 col8" >mikedparrott</td>
#       <td id="T_fa948_row1_col9" class="data row1 col9" >1</td>
#     </tr>
#     <tr>
#       <th id="T_fa948_level0_row2" class="row_heading level0 row2" >2</th>
#       <td id="T_fa948_row2_col0" class="data row2 col0" >82.82%</td>
#       <td id="T_fa948_row2_col1" class="data row2 col1" >81.29%</td>
#       <td id="T_fa948_row2_col2" class="data row2 col2" >81.70%</td>
#       <td id="T_fa948_row2_col3" class="data row2 col3" >80.96%</td>
#       <td id="T_fa948_row2_col4" class="data row2 col4" >sklearn</td>
#       <td id="T_fa948_row2_col5" class="data row2 col5" >LogisticRegression

# %%
# Compare two or more models
data=mycompetition.compare_models([2,3], verbose=1)
mycompetition.stylize_compare(data)
# Out:
# <style type="text/css">
# #T_607f8_ caption {
#   color: black;
#   font-size: 18px;
# }
# #T_607f8_row0_col2, #T_607f8_row0_col3, #T_607f8_row9_col2, #T_607f8_row11_col2 {
#   background: tomato;
# }
# </style>
# <table id="T_607f8_">
#   <caption>Model type: LogisticRegression</caption>
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th class="col_heading level0 col0" >param_name</th>
#       <th class="col_heading level0 col1" >default_value</th>
#       <th class="col_heading level0 col2" >model_version_2</th>
#       <th class="col_heading level0 col3" >model_version_3</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_607f8_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_607f8_row0_col0" class="data row0 col0" >C</td>
#       <td id="T_607f8_row0_col1" class="data row0 col1" >1.000000</td>
#       <td id="T_607f8_row0_col2" class="data row0 col2" >10</td>
#       <td id="T_607f8_row0_col3" class="data row0 col3" >0.010000</td>
#     </tr>
#     <tr>
#       <th id="T_607f8_level0_row1" class="row_heading level0 row1" >1</th>
#       <td id="T_607f8_row1_col0" class="data row1 col0" >class_weight</td>
#       <td id="T_607f8_row1_col1" class="data row1 col1" >None</td>
#       <td id="T_607f8_row1_col2" class="data row1 col2" >None</td>
#       <td id="T_607f8_row1_col3" class="data row1 col3" >None</td>
#     </tr>
#     <tr>
#       <th id="T_607f8_level0_row2" class="row_heading level0 row2" >2</th>
#       <td id="T_607f8_row2_col0" class="data row2 col0" >dual</td>
#       <td id="T_607f8_row2_col1" class="data row2 col1" >False</td>
#       <td id="T_607f8_row2_col2" class="data row2 col2" >False</td>
#       <td id="T_607f8_row2_col3" class="data row2 col3" >False</td>
#     </tr>
#     <tr>
#       <th id="T_607f8_level0_row3" class="row_heading level0 row3" >3</th>
#       <td id="T_607f8_row3_col0" class="data row3 col0" >fit_intercept</td>
#       <td id="T_607f8_row3_col1" class="data row3 col1" >True</td>
#       <td id="T_607f8_row3_col2" class="data row3 col2" >True</td>
#       <td id="T_607f8_row3_col3" class="data row3 col3" >True</td>
#     </tr>
#     <tr>
#       <th id="T_607f8_level0_row4" class="row_heading level0 row4" >4</th>
#       <td id="T_607f8_row4_col0" class="data row4 col0" >intercept_scaling</td>
#       <td id="T_607f8_row4_col1" class="data row4 col1" >1</td>
#       <td id="T_607f8_row4_col2" class="data row4 col2" >1</td>
#       <td id="T_607f8_row4_col3" class="data row4 col3" >1</td>
#     </tr>
#     <tr>
#       <th id="T_607f8_level0_row5" class="row_heading level0 row5" >5</th>
#       <td id="T_607f8_row5_col0" class="data row5 col0" >l1_ratio</td>
#       <td id="T_607f8_row5_col1" class="data row5 col1" >None</td>
#       <td id="T_607f8_row5_col2" class="data row5 col2" >None</td>
#       <td id="T_607f8_row5_col3" class="data row5 col3" >None</td>
#     </tr>
#     <tr>
#       <th id="T_607f8_level0_row6" class="row_heading level0 row6" >6</th>
#       <td id="T_607f8_row6_col0" class="data row6 col0" >max_iter</td>
#       <td id="T_607f8_row6_col1" class="data row6 col1" >100</td>
#       <td id="T_607f8_row6_col2" class="data row6 col2" >100</td>
#       <td id="T_607f8_row6_col3" class="data row6 col3" >100</td>
#     </tr>
#     <tr>
#       <th id="T_607f8_level0_row7" class="row_heading level0 row7" >7</th>
#       <td id="T_607f8_row7_col0" class="data row7 col0" >multi_class</td>
#       <td id="T_607f8_row7_col1" class="data row7 col1" >auto</td>
#       <td id="T_607f8_row7_col2" class="data row7 col2" >auto</td>
#       <td id="T_607f8_row7_col3" class="data row7 col3" >auto</td>
#     </tr>
#     <tr>
#       <th id="T_607f8_level0_row8" class="row_heading level0 row8" >8</th>
#       <td id="T_607f8_row8_col0" class="data row8 col0" >n_jobs</td>
#       <td id="T_607f8_row8_col1" class="data row8 col1" >None</td>
#       <td id="T_607f8_row8_col2" class="data row8 col2" >None</td>
#       <td id="T_607f8_row8_col3" class="data row8 col3" >None</td>
#     </tr>
#     <tr>
#       <th id="T_607f8_level0_row9" class="row_heading level0 row9" >9</th>
#       <td id="T_607f8_row9_col0" class="data row9 col0" >penalty</td>
#       <td id="T_607f8_row9_col1" class="data row9 col1" >l2</td>
#       <td id="T_607f8_row9_col2" class="data row9 col2" >l1</td>
#       <td id="T_607f8_row9_col3" class="data row9 col3" >l2</td>
#     </tr>
#     <tr>
#       <th id="T_607f8_level0_row10" class="row_heading level0 row10" >10</th>
#       <td id="T_607f8_row10_col0" class="data row10 col0" >random_state</td>
#       <td id="T_607f8_row10_col1" class="data row10 col1" >None</td>
#       <td id="T_607f8_row10_col2" class="data row10 col2" >None</td>
#       <td id="T_607f8_row10_col3" class="data row10 col3" >None</td>
#     </tr>
#     <tr>
#       <th id="T_607f8_level0_row11" class="row_heading level0 row11" >11</th>
#       <td id="T_607f8_row11_col0" class="data row11 col0" >solver</td>
#       <td id="T_607f8_row11_col1" class="data row11 col1" >lbfgs</td>
#       <td id="T_607f8_row11_col2" class="data row11 col2" >liblinear</td>
#       <td id="T_607f8_row11_col3" class="data row11 col3" >lbfgs</td>
#     </tr>
#     <tr>
#       <th id="T_607f8_level0_row12" class="row_heading level0 row12" >12</th>
#       <td id="T_607f8_row12_col0" class="data row12 col0" >tol</td>
#       <td id="T_607f8_row12_col1" class="data row12 col1" >0.000100</td>
#       <td id="T_607f8_row12_col2" class="data row12 col2" >0.000100</td>
#       <td id="T_607f8_row12_col3" class="data row12 col3" >0.000100</td>
#     </tr>
#     <tr>
#       <th id="T_607f8_level0_row13" class="row_heading level0 row13" >13</th>
#       <td id="T_607f8_row13_col0" class="data row13 col0" >verbose</td>
#       <td id="T_607f8_row13_col1" class="data row13 col1" >0</td>
#       <td id="T_607f8_row13_col2" class="data row13 col2" >0</td>
#       <td id="T_607f8_row13_col3" class="data row13 col3" >0</td>
#     </tr>
#     <tr>
#       <th id="T_607f8_level0_row14" class="row_heading level0 row14" >14</th>
#       <td id="T_607f8_row14_col0" class="data row14 col0" >warm_start</td>
#       <td id="T_607f8_row14_col1" class="data row14 col1" >False</td>
#       <td id="T_607f8_row14_col2" class="data row14 col2" >False</td>
#       <td id="T_607f8_row14_col3" class="data row14 col3" >False</td>
#     </tr>
#   </tbody>
# </table>

# %%
# Here are several classic ML architectures you can consider choosing from to experiment with next:
from sklearn.neighbors import KNeighborsClassifier
from sklearn.svm import SVC
from sklearn.ensemble import RandomForestClassifier
from sklearn.tree import DecisionTreeRegressor
from sklearn.ensemble import BaggingClassifier
from sklearn.ensemble import GradientBoostingClassifier

#Example code to fit model:
model = GradientBoostingClassifier(n_estimators=50, learning_rate=1.0,
    max_depth=1, random_state=0).fit(preprocessor(X_train), y_train_labels)
model.score(preprocessor(X_train), y_train_labels)

#-- Generate predicted values (a list of predicted labels "real" or "fake")
prediction_labels = model.predict(preprocessor(X_test))

# Submit model to Competition Leaderboard
mycompetition.submit_model(model = model,
                                 preprocessor ="preprocessor.zip",
                                 prediction_submission=prediction_labels)
# Out:
# This ORT build has ['AzureExecutionProvider', 'CPUExecutionProvider'] enabled. Since ORT 1.9, you are required to explicitly set the providers parameter when instantiating InferenceSession. For example, onnxruntime.InferenceSession(..., providers=['AzureExecutionProvider', 'CPUExecutionProvider'], ...)
#
# Insert search tags to help users find your model (optional):
# Provide any useful notes about your model (optional):
# Your model has been submitted to experiment as model version 8.
#
# Visit your Model Playground Page for more.
# https://www.modelshare.ai/detail/model:3860
